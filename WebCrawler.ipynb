# %% [markdown]
# <a href="https://colab.research.google.com/github/eeshwar369/WebCrawler/blob/main/WebCrawler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install "crawl4ai @ git+https://github.com/unclecode/crawl4ai.git"
# Out:
# ...
#   Cloning https://github.com/unclecode/crawl4ai.git to /tmp/pip-install-eduopi9c/crawl4ai_bcb0a44ace40414cb0e3db22e2b9bd2d
#   Running command git clone --filter=blob:none --quiet https://github.com/unclecode/crawl4ai.git /tmp/pip-install-eduopi9c/crawl4ai_bcb0a44ace40414cb0e3db22e2b9bd2d
#   Resolved https://github.com/unclecode/crawl4ai.git to commit e5e6a34e8097cb5ff72c026b19859b5b98246378
#   Preparing metadata (setup.py) ... done
# ...

# %%
from crawl4ai import WebCrawler

# %%
crawler = WebCrawler()
# Out:
# [LOG] 🚀 Initializing LocalSeleniumCrawlerStrategy

# %%
crawler.warmup()
# Out:
# [LOG] 🌤️  Warming up the WebCrawler
# [LOG] 🌞 WebCrawler is ready to crawl

# %%
result = crawler.run(
    url = "https://vardhaman.org/placement-status/"
)

# Print the extracted content
print(result.markdown)
# Out:
# [LOG] 🚀 Crawling done for https://vardhaman.org/placement-status/, success: True, time taken: 8.384809255599976 seconds
# [LOG] 🚀 Content extracted for https://vardhaman.org/placement-status/, success: True, time taken: 1.3454670906066895 seconds
# [LOG] 🔥 Extracting semantic blocks for https://vardhaman.org/placement-status/, Strategy: NoExtractionStrategy
# [LOG] 🚀 Extraction done for https://vardhaman.org/placement-status/, time taken: 1.3473844528198242 seconds.
# Skip to content
#
# Vardhaman College of Engineering
#
#   * Student Corner
#   * Staff Login
#   * Vardhaman E-Mail
#   * Faculty Profiles
#   * Alumni
#
# __LOGIN
#
# Vision, Mission & Core Values Campus TourIQACNAAC NIRFNBAUGC
#
#   * Student Corner
#   * Staff Login
#   * Vardhaman E-Mail
#   * Faculty Profiles
#   * Alumni
#
# __LOGIN
#
#   * Student Corner
#   * Staff Login
#   * Vardhaman E-Mail
#   * Faculty Profiles
#   * Alumni
#
# __LOGIN
#
# Vardhaman
#
# Vardhaman College of Engineering
#
# ...
